# %%
import pandas as pd
import nltk
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer, WordNetLemmatizer
import string

# Step 1: Load the dataset
df = pd.read_csv('Datafiniti_Amazon_Consumer_Reviews_of_Amazon_Products_May19.csv')

# Step 2: Data Cleaning
# Check for missing values
print(df.isnull().sum())

# Handle missing values if any
df.dropna(inplace=True)

# Step 3: Text Preprocessing
# Tokenization and lowercase conversion
# Step 3: Text Preprocessing
# Tokenization and lowercase conversion
def tokenize_and_lowercase(text):
    tokens = nltk.word_tokenize(text)
    tokens = [token.lower() for token in tokens]
    return ' '.join(tokens)

# Identify the correct column name for customer reviews
# Replace 'reviews' with the actual column name that contains the reviews
df['cleaned_reviews'] = df['actual_column_name'].apply(tokenize_and_lowercase)


# Remove punctuation and numbers
def remove_punctuation_and_numbers(text):
    translator = str.maketrans('', '', string.punctuation + string.digits)
    return text.translate(translator)

df['cleaned_reviews'] = df['cleaned_reviews'].apply(remove_punctuation_and_numbers)

# Remove stop words
nltk.download('stopwords')
stop_words = set(stopwords.words('english'))

def remove_stop_words(text):
    words = text.split()
    words = [word for word in words if word not in stop_words]
    return ' '.join(words)

df['cleaned_reviews'] = df['cleaned_reviews'].apply(remove_stop_words)

# Stemming
stemmer = PorterStemmer()

def apply_stemming(text):
    words = text.split()
    words = [stemmer.stem(word) for word in words]
    return ' '.join(words)

# Identify the correct column name for customer reviews (e.g., 'reviews.text')
df['cleaned_reviews'] = df['reviews.text'].apply(tokenize_and_lowercase)


# Lemmatization
nltk.download('wordnet')
lemmatizer = WordNetLemmatizer()

def apply_lemmatization(text):
    words = text.split()
    words = [lemmatizer.lemmatize(word) for word in words]
    return ' '.join(words)

# Identify the correct column name for customer reviews (e.g., 'reviews.text')
# Identify the correct column name for customer reviews (e.g., 'reviews.text')
df['cleaned_reviews'] = df['reviews.text'].apply(tokenize_and_lowercase)



# Step 4: Exploratory Data Analysis
# You can now explore the preprocessed data to identify common words, word frequencies, or other patterns using techniques like word cloud, word frequency analysis, or topic modeling.

# Example of word frequency analysis
from collections import Counter
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Tokenize again for word frequency analysis
tokenized_reviews = df['cleaned_reviews'].apply(nltk.word_tokenize)
words = [word for tokens in tokenized_reviews for word in tokens]

word_freq = Counter(words)
word_freq_most_common = word_freq.most_common(20)

# Plotting word frequency
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(dict(word_freq_most_common))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()
# Out:
# id                         0
# dateAdded                  0
# dateUpdated                0
# name                       0
# asins                      0
# brand                      0
# categories                 0
# primaryCategories          0
# imageURLs                  0
# keys                       0
# manufacturer               0
# manufacturerNumber         0
# reviews.date               0
# reviews.dateSeen           0
# reviews.didPurchase    28323
# reviews.doRecommend    12246
# reviews.id             28291
# reviews.numHelpful     12217
# reviews.rating             0
# reviews.sourceURLs         0
# reviews.text               0
# reviews.title              0
# reviews.username           5
# sourceURLs                 0
# dtype: int64
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ...
